# %% [markdown]
# This notebook verifies the canonical enriched dataset:
#
# - Official file: `data/processed_icd/diabetes_clinical_enriched.csv`
# - Azure ML uses its copy: `data_clinical_upload/diabetes_clinical.csv`
# - Older version is archived at `data/archive/diabetes_clinical_enriched_legacy_v1.csv`.

# %%
import pandas as pd

# Load the new enriched file created by icd_enrich.py
df = pd.read_csv("../data/processed_icd/diabetes_clinical_enriched.csv")

df.shape
# Out:
# C:\Users\achar\AppData\Local\Temp\ipykernel_20404\543994914.py:4: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/processed_icd/diabetes_clinical_enriched.csv")
# (101766, 52)

# %%
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)    NaN
# 1        149190     55629189        Caucasian  Female  [10-20)    NaN
# 2         64410     86047875  AfricanAmerican  Female  [20-30)    NaN
# 3        500364     82442376        Caucasian    Male  [30-40)    NaN
# 4         16680     42519267        Caucasian    Male  [40-50)    NaN
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... glyburide-metformin glipizide-metformin  \
# 0                 1  ...                  No                  No
# ...

# %%
df['Primary_Diagnosis_Group'].value_counts()
# Out:
# Primary_Diagnosis_Group
# I00-I99 (Diseases of the circulatory system)                       30437
# Other (Genitourinary, Mental, Skin, etc.)                          21644
# J00-J99 (Diseases of the respiratory system)                       14423
# K00-K93 (Diseases of the digestive system)                          9475
# E08-E13 (Diabetes mellitus)                                         8757
# S00-T98 (Injury, poisoning and consequences of external causes)     6974
# M00-M99 (Diseases of the musculoskeletal system)                    4957
# C00-D48 (Neoplasms)                                                 3433
# Z00-Z99 (Factors influencing health status)                         1644
# Unknown                                                               21
# V01-Y98 (External causes of morbidity)                                 1
# Name: count, dtype: int64

# %%
df['High_Risk_A1C'].value_counts(dropna=False)
# Out:
# High_Risk_A1C
# 0    93550
# 1     8216
# Name: count, dtype: int64

# %%
import pandas as pd

df = pd.read_csv("../data/processed_icd/train/train.csv")
print("readmitted" in df.columns)  # should be False
print("readmitted_30d_binary" in df.columns)  # should be True

missing_count = df['readmitted_30d_binary'].isnull().sum()
print(f"Total Missing Values: {missing_count}")
# Out:
# False
# True
# Total Missing Values: 0
